# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Loading Data

# %%
df=pd.read_csv(r"C:\Users\JYOTHI\Downloads\archive (5)\KaggleV2-May-2016.csv")
df
# Out:
#            PatientId  AppointmentID Gender          ScheduledDay  \
# 0       2.987250e+13        5642903      F  2016-04-29T18:38:08Z
# 1       5.589978e+14        5642503      M  2016-04-29T16:08:27Z
# 2       4.262962e+12        5642549      F  2016-04-29T16:19:04Z
# 3       8.679512e+11        5642828      F  2016-04-29T17:29:31Z
# 4       8.841186e+12        5642494      F  2016-04-29T16:07:23Z
# ...              ...            ...    ...                   ...
# 110522  2.572134e+12        5651768      F  2016-05-03T09:15:35Z
# 110523  3.596266e+12        5650093      F  2016-05-03T07:27:33Z
# 110524  1.557663e+13        5630692      F  2016-04-27T16:03:52Z
# 110525  9.213493e+13        5630323      F  2016-04-27T15:09:23Z
# 110526  3.775115e+14        5629448      F  2016-04-27T13:30:56Z
#
#               AppointmentDay  Age      Neighbourhood  Scholarship  \
# 0       2016-04-29T00:00:00Z   62    JARDIM DA PENHA            0
# ...

# %%
df_app=df.copy()
df_app
# Out:
#            PatientId  AppointmentID Gender          ScheduledDay  \
# 0       2.987250e+13        5642903      F  2016-04-29T18:38:08Z
# 1       5.589978e+14        5642503      M  2016-04-29T16:08:27Z
# 2       4.262962e+12        5642549      F  2016-04-29T16:19:04Z
# 3       8.679512e+11        5642828      F  2016-04-29T17:29:31Z
# 4       8.841186e+12        5642494      F  2016-04-29T16:07:23Z
# ...              ...            ...    ...                   ...
# 110522  2.572134e+12        5651768      F  2016-05-03T09:15:35Z
# 110523  3.596266e+12        5650093      F  2016-05-03T07:27:33Z
# 110524  1.557663e+13        5630692      F  2016-04-27T16:03:52Z
# 110525  9.213493e+13        5630323      F  2016-04-27T15:09:23Z
# 110526  3.775115e+14        5629448      F  2016-04-27T13:30:56Z
#
#               AppointmentDay  Age      Neighbourhood  Scholarship  \
# 0       2016-04-29T00:00:00Z   62    JARDIM DA PENHA            0
# ...

# %%
df_app.head()
# Out:
#       PatientId  AppointmentID Gender          ScheduledDay  \
# 0  2.987250e+13        5642903      F  2016-04-29T18:38:08Z
# 1  5.589978e+14        5642503      M  2016-04-29T16:08:27Z
# 2  4.262962e+12        5642549      F  2016-04-29T16:19:04Z
# 3  8.679512e+11        5642828      F  2016-04-29T17:29:31Z
# 4  8.841186e+12        5642494      F  2016-04-29T16:07:23Z
#
#          AppointmentDay  Age      Neighbourhood  Scholarship  Hipertension  \
# 0  2016-04-29T00:00:00Z   62    JARDIM DA PENHA            0             1
# 1  2016-04-29T00:00:00Z   56    JARDIM DA PENHA            0             0
# 2  2016-04-29T00:00:00Z   62      MATA DA PRAIA            0             0
# 3  2016-04-29T00:00:00Z    8  PONTAL DE CAMBURI            0             0
# 4  2016-04-29T00:00:00Z   56    JARDIM DA PENHA            0             1
#
#    Diabetes  Alcoholism  Handcap  SMS_received No-show
# 0         0           0        0             0      No
# ...

# %%
df_app.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 110527 entries, 0 to 110526
# Data columns (total 14 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   PatientId       110527 non-null  float64
#  1   AppointmentID   110527 non-null  int64
#  2   Gender          110527 non-null  object
#  3   ScheduledDay    110527 non-null  object
#  4   AppointmentDay  110527 non-null  object
#  5   Age             110527 non-null  int64
#  6   Neighbourhood   110527 non-null  object
#  7   Scholarship     110527 non-null  int64
#  8   Hipertension    110527 non-null  int64
#  9   Diabetes        110527 non-null  int64
#  10  Alcoholism      110527 non-null  int64
#  11  Handcap         110527 non-null  int64
#  12  SMS_received    110527 non-null  int64
#  13  No-show         110527 non-null  object
# dtypes: float64(1), int64(8), object(5)
# memory usage: 11.8+ MB

# %% [markdown]
# # By seeing above we can identify that there are no null values present in this dataset.

# %%
df_app.shape
# Out:
# (110527, 14)

# %%
df_app.describe()
# Out:
#           PatientId  AppointmentID            Age    Scholarship  \
# count  1.105270e+05   1.105270e+05  110527.000000  110527.000000
# mean   1.474963e+14   5.675305e+06      37.088874       0.098266
# std    2.560949e+14   7.129575e+04      23.110205       0.297675
# min    3.921784e+04   5.030230e+06      -1.000000       0.000000
# 25%    4.172614e+12   5.640286e+06      18.000000       0.000000
# 50%    3.173184e+13   5.680573e+06      37.000000       0.000000
# 75%    9.439172e+13   5.725524e+06      55.000000       0.000000
# max    9.999816e+14   5.790484e+06     115.000000       1.000000
#
#         Hipertension       Diabetes     Alcoholism        Handcap  \
# count  110527.000000  110527.000000  110527.000000  110527.000000
# mean        0.197246       0.071865       0.030400       0.022248
# std         0.397921       0.258265       0.171686       0.161543
# min         0.000000       0.000000       0.000000       0.000000
# ...

# %%
df_app.duplicated().sum()
# Out:
# 0

# %%
# finding number of unique values
df_app["PatientId"].value_counts().count()
# Out:
# 62299

# %%
df_app.duplicated(['PatientId','No-show']).sum()
# Out:
# 38710

# %% [markdown]
# # from the above we can see that there are 38710 duplicate values that are present in the columns like PatientId and No-show and we will remove them

# %%
age=df_app[df_app["Age"] == -1]
age
# Out:
#           PatientId  AppointmentID Gender          ScheduledDay  \
# 99832  4.659432e+14        5775010      F  2016-06-06T08:58:13Z
#
#              AppointmentDay  Age Neighbourhood  Scholarship  Hipertension  \
# 99832  2016-06-06T00:00:00Z   -1         ROMÃO            0             0
#
#        Diabetes  Alcoholism  Handcap  SMS_received No-show
# 99832         0           0        0             0      No

# %% [markdown]
# # Data Cleaning

# %%
df_app.drop(index=99832,inplace=True)

# %%
df_app["Age"].describe()
# Out:
# count    110526.000000
# mean         37.089219
# std          23.110026
# min           0.000000
# 25%          18.000000
# 50%          37.000000
# 75%          55.000000
# max         115.000000
# Name: Age, dtype: float64

# %%
df_app.drop_duplicates(['PatientId','No-show'],inplace=True)

# %%
df_app.shape
# Out:
# (71816, 14)

# %%
df_app.drop(['PatientId','AppointmentID','ScheduledDay','AppointmentDay'],axis=1,inplace=True)

# %%
df_app.head()
# Out:
#   Gender  Age      Neighbourhood  Scholarship  Hipertension  Diabetes  \
# 0      F   62    JARDIM DA PENHA            0             1         0
# 1      M   56    JARDIM DA PENHA            0             0         0
# 2      F   62      MATA DA PRAIA            0             0         0
# 3      F    8  PONTAL DE CAMBURI            0             0         0
# 4      F   56    JARDIM DA PENHA            0             1         1
#
#    Alcoholism  Handcap  SMS_received No-show
# 0           0        0             0      No
# 1           0        0             0      No
# 2           0        0             0      No
# 3           0        0             0      No
# 4           0        0             0      No

# %% [markdown]
# # Data Visualization

# %%
df_app.hist(figsize=(18,8))
# Out:
# array([[<Axes: title={'center': 'Age'}>,
#         <Axes: title={'center': 'Scholarship'}>,
#         <Axes: title={'center': 'Hipertension'}>],
#        [<Axes: title={'center': 'Diabetes'}>,
#         <Axes: title={'center': 'Alcoholism'}>,
#         <Axes: title={'center': 'Handcap'}>],
#        [<Axes: title={'center': 'SMS_received'}>, <Axes: >, <Axes: >]],
#       dtype=object)

# %%
show=df_app['No-show'] == 'No'
noshow=df_app['No-show'] == 'Yes'

# %%
df_app[show].count()
# Out:
# Gender           54153
# Age              54153
# Neighbourhood    54153
# Scholarship      54153
# Hipertension     54153
# Diabetes         54153
# Alcoholism       54153
# Handcap          54153
# SMS_received     54153
# No-show          54153
# dtype: int64

# %%
df_app[noshow].count()
# Out:
# Gender           17663
# Age              17663
# Neighbourhood    17663
# Scholarship      17663
# Hipertension     17663
# Diabetes         17663
# Alcoholism       17663
# Handcap          17663
# SMS_received     17663
# No-show          17663
# dtype: int64

# %% [markdown]
# # plotting histogram for Age by no show

# %%
plt.figure(figsize=(10,6))
plt.hist(df_app[show]['Age'],bins=15,color='red',alpha=0.5,label='SHOW')
plt.hist(df_app[noshow]['Age'],bins=15,color='blue',alpha=0.5,label='NO SHOW')
plt.title("Ages By No Show")
plt.xlabel('Age')
plt.ylabel('Patient num')
plt.legend()
plt.show()

# %% [markdown]
# # plotting barplot to know that the  age and chronic diseases affect the attendance together

# %%
plt.figure(figsize=(16,4))
df_app[show].groupby(['Hipertension','Diabetes'])['Age'].mean().plot(kind='bar',color='pink',label='show')
df_app[noshow].groupby(['Hipertension','Diabetes'])['Age'].mean().plot(kind='bar',color='blue',label='noshow')
plt.title('comparision according to age, chroinc diseases')
plt.xlabel('chronic diseases')
plt.ylabel('mean age')
plt.legend()
plt.show()

# %%
df_app[show].groupby(['Hipertension','Diabetes'])['Age'].mean()
# Out:
# Hipertension  Diabetes
# 0             0           30.713360
#               1           53.701370
# 1             0           60.270517
#               1           63.764303
# Name: Age, dtype: float64

# %%
df_app[noshow].groupby(['Hipertension','Diabetes'])['Age'].mean()
# Out:
# Hipertension  Diabetes
# 0             0           28.768691
#               1           49.481172
# 1             0           58.650380
#               1           62.913282
# Name: Age, dtype: float64

# %% [markdown]
# # plotting the pie chart for comparing between attendance by gender.

# %%
df_app['Gender'][show].value_counts(normalize=True).plot(kind='pie',label="show")
plt.title("Comparing the attendance by gender for show column")
plt.xlabel("Gender")
plt.ylabel("Patients Number")
plt.legend()
plt.show()

# %%
df_app['Gender'][noshow].value_counts(normalize=True).plot(kind='pie',label="show")
plt.title("Comparing the attendance by gender for noshow column")
plt.xlabel("Gender")
plt.ylabel("Patients Number")
plt.legend()
plt.show()

# %%
df_app[show].groupby('Gender')['Age'].mean().plot(kind='bar', color = 'red', label = 'show')
df_app[noshow].groupby('Gender')['Age'].mean().plot(kind='bar', color = 'blue',label = 'noShow')

plt.title('Comparison according to age, Gender and attendance')
plt.xlabel('Gender')
plt.ylabel('mean age')
plt.legend()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
df_app[show].groupby('Gender')['Age'].mean()
# Out:
# Gender
# F    39.130292
# M    33.766269
# Name: Age, dtype: float64

# %%
df_app[noshow].groupby('Gender')['Age'].mean()
# Out:
# Gender
# F    36.06501
# M    31.22040
# Name: Age, dtype: float64

# %%
df_app[show].groupby('Gender')['Age'].median()
# Out:
# Gender
# F    39.0
# M    32.0
# Name: Age, dtype: float64

# %%
df_app[noshow].groupby('Gender')['Age'].median()
# Out:
# Gender
# F    34.0
# M    29.0
# Name: Age, dtype: float64

# %% [markdown]
# # There is no correlation between age and gender affecting the show rate. The mean of gender ages are almost the same

# %% [markdown]
# ## Plotting hist graph to know that  reciving sms affect the attend.

# %%
df_app['SMS_received'][show].hist(alpha = 0.5, bins = 12, color ='red',label ='show')
df_app['SMS_received'][noshow].hist(alpha = 0.5, bins = 12, color ='blue',label ='noshow')
plt.title("Comparing accordinng to sms receiving")
plt.xlabel("SMS")
plt.ylabel("Patient num")
plt.legend()
plt.show()

# %% [markdown]
# # Number of showing patients without receiving sms is greater than showing patients with receiving sms, which mean that we need to revisit our sms campaign

# %%
#does neighbourhood affect the attendance
plt.figure(figsize=(14,8))
df_app['Neighbourhood'][show].value_counts().plot(kind='bar', color = 'blue', label = 'show')
df_app['Neighbourhood'][noshow].value_counts().plot(kind='bar', color = 'red', label = 'noShow')

plt.title('comparison according to Neighbourhood')
plt.xlabel('Neighbourhood')
plt.ylabel('Patient Num')
plt.legend()
plt.show()

# %% [markdown]
# # This means neighbourhood has a great affect on the attendance

# %%
plt.figure(figsize=(14,8))
df_app[show].groupby('Neighbourhood').SMS_received.mean().plot(kind = 'bar', color = 'blue', label = 'show')
df_app[noshow].groupby('Neighbourhood').SMS_received.mean().plot(kind = 'bar', color = 'red', label = 'noShow')

plt.title('Comparison according to Neighbourhood, SMS_receiving')
plt.xlabel('Neighbourhood')
plt.ylabel('patients num')
plt.legend()
plt.show()

# %% [markdown]
# # SMS has response in only 5 neighbourhoods

# %%
plt.figure(figsize=(14,8))
df_app[show].groupby('Neighbourhood').Age.mean().plot(kind = 'bar', color = 'blue', label = 'show')
df_app[noshow].groupby('Neighbourhood').Age.mean().plot(kind = 'bar', color = 'red', label = 'noShow')

plt.title('Comparison according to Neighbourhood, Age')
plt.xlabel('Neighbourhood')
plt.ylabel('mean Age')
plt.legend()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# # Patients attendance from specific neighbourhood differ according to ages

# %% [markdown]
# # Conclusions:
# # Neighbourhood has a great effect on attendance or not.
#
# # Number of showing patients from specific neighbourhood affected by receving SMS and ages.
#
# # Age has a clear influence on the showing rate.
#
# # Number of showing patients without reciving sms is greater than showing patients with reciving sms, which mean that we need to revisit our sms campaign.
#
# # No clear correlation between showing and gender, chronic diseases, enrollement in the welfare program.
